# %%
import sys
sys.path.append("..")
from aluneth.mathematics.geometry.geoclidean.euclidean_primitives import *
import numpy as np
import os
import shutil

# %%
concept = [
    'l1 = line(p1(), p2())',
    'c1* = circle(p1(), p2())',
    'c2* = circle(p2(), p1())',
    'l2 = line(p1(), p3(c1, c2))',
    'l3 = line(p2(), p3()))'
]


for i in range(3):
    generate_concept(concept, mark_points=False, show_plots=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb Cell 2' in <cell line: 10>()
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000002?line=0'>1</a> concept = [
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000002?line=1'>2</a>     'l1 = line(p1(), p2())',
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000002?line=2'>3</a>     'c1* = circle(p1(), p2())',
#    (...)
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000002?line=5'>6</a>     'l3 = line(p2(), p3()))'
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000002?line=6'>7</a> ]
#      <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000002?line=9'>10</a> for i in range(3):
# ---> <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000002?line=10'>11</a>     generate_concept(concept, mark_points=False, show_plots=True)
#
# File ~/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py:212, in generate_concept(rules, mark_points, steps_path, path, show_plots)
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py?line=209'>210</a>     plt.close()
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py?line=210'>211</a>     continue
# --> <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py?line=211'>212</a> plt.pause(5)
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py?line=212'>213</a> plt.cla()
#
# File ~/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py:569, in pause(interval)
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=566'>567</a>         canvas.draw_idle()
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=567'>568</a>     show(block=False)
# --> <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=568'>569</a>     canvas.start_event_loop(interval)
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=569'>570</a> else:
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=570'>571</a>     time.sleep(interval)
#
# File ~/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py:2519, in FigureCanvasBase.start_event_loop(self, timeout)
#    <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2516'>2517</a> while self._looping and counter * timestep < timeout:
#    <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2517'>2518</a>     self.flush_events()
# -> <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2518'>2519</a>     time.sleep(timestep)
#    <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2519'>2520</a>     counter += 1
#
# KeyboardInterrupt:

# %%
concept = [
    'c1 = circle(p1(), p2())',
    'c2 = circle(p3(c1), p4())',
    'l3 = line(p5(c1), p6(c1, c2))'
]

for i in range(3):
    generate_concept(concept, mark_points=False, show_plots=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb Cell 3' in <cell line: 10>()
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000001?line=0'>1</a> concept = [
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000001?line=1'>2</a>     'l1 = line(p1(), p2())',
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000001?line=2'>3</a>     'c1* = circle(p1(), p2())',
#    (...)
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000001?line=5'>6</a>     'l3 = line(p2(), p3()))'
#       <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000001?line=6'>7</a> ]
#      <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000001?line=9'>10</a> for i in range(3):
# ---> <a href='vscode-notebook-cell:/Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/example.ipynb#ch0000001?line=10'>11</a>     generate_concept(concept, mark_points=False, show_plots=True)
#
# File ~/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py:212, in generate_concept(rules, mark_points, steps_path, path, show_plots)
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py?line=209'>210</a>     plt.close()
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py?line=210'>211</a>     continue
# --> <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py?line=211'>212</a> plt.pause(5)
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/aluneth/mathematics/geometry/geoclidean/euclidean_primitives.py?line=212'>213</a> plt.cla()
#
# File ~/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py:569, in pause(interval)
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=566'>567</a>         canvas.draw_idle()
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=567'>568</a>     show(block=False)
# --> <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=568'>569</a>     canvas.start_event_loop(interval)
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=569'>570</a> else:
#     <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/pyplot.py?line=570'>571</a>     time.sleep(interval)
#
# File ~/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py:2519, in FigureCanvasBase.start_event_loop(self, timeout)
#    <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2516'>2517</a> while self._looping and counter * timestep < timeout:
#    <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2517'>2518</a>     self.flush_events()
# -> <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2518'>2519</a>     time.sleep(timestep)
#    <a href='file:///Users/melkor/miniforge3/envs/Melkor/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2519'>2520</a>     counter += 1
#
# KeyboardInterrupt:
